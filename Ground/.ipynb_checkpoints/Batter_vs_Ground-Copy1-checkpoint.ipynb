# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np 
import os
import pandas as pd

# %%
df1 = pd.read_csv('../archive/IPL_Ball_by_Ball_2008_2022.csv')
df1.dataframeName = 'deliveries.csv'

# %%
df1.head(5)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
len(df1)
# Out:
# 225954

# %%
player_subset = df1[df1["batter"] == 'SN Khan']
player_subset
# Out:
#              ID  innings  overs  ballnumber   batter       bowler non-striker  \
# 1231    1304115        1      5           5  SN Khan    JJ Bumrah     RR Pant
# 1232    1304115        1      5           6  SN Khan    JJ Bumrah     RR Pant
# 1236    1304115        1      6           4  SN Khan   M Markande     RR Pant
# 1239    1304115        1      7           1  SN Khan  RP Meredith     RR Pant
# 1241    1304115        1      7           3  SN Khan  RP Meredith     RR Pant
# ...         ...      ...    ...         ...      ...          ...         ...
# 112202   829745        2     12           1  SN Khan    IC Pandey     V Kohli
# 112205   829745        2     12           4  SN Khan    IC Pandey     V Kohli
# 112208   829745        2     13           1  SN Khan    RA Jadeja     V Kohli
# 112209   829745        2     13           2  SN Khan    RA Jadeja     V Kohli
# 112210   829745        2     13           3  SN Khan    RA Jadeja     V Kohli
#
#        extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 1231          NaN            0           0          0             0
# 1232          NaN            6           0          6             0
# 1236          NaN            1           0          1             0
# 1239          NaN            1           0          1             0
# 1241          NaN            1           0          1             0
# ...           ...          ...         ...        ...           ...
# 112202        NaN            1           0          1             0
# 112205        NaN            1           0          1             0
# 112208        NaN            6           0          6             0
# 112209        NaN            2           0          2             0
# 112210        NaN            0           0          0             0
#
#         isWicketDelivery player_out    kind fielders_involved  \
# 1231                   0        NaN     NaN               NaN
# 1232                   0        NaN     NaN               NaN
# 1236                   0        NaN     NaN               NaN
# 1239                   0        NaN     NaN               NaN
# 1241                   0        NaN     NaN               NaN
# ...                  ...        ...     ...               ...
# 112202                 0        NaN     NaN               NaN
# 112205                 0        NaN     NaN               NaN
# 112208                 0        NaN     NaN               NaN
# 112209                 0        NaN     NaN               NaN
# 112210                 1    SN Khan  caught         MM Sharma
#
#                         BattingTeam
# 1231                 Delhi Capitals
# 1232                 Delhi Capitals
# 1236                 Delhi Capitals
# 1239                 Delhi Capitals
# 1241                 Delhi Capitals
# ...                             ...
# 112202  Royal Challengers Bangalore
# 112205  Royal Challengers Bangalore
# 112208  Royal Challengers Bangalore
# 112209  Royal Challengers Bangalore
# 112210  Royal Challengers Bangalore
#
# [394 rows x 17 columns]

# %%
df2 = pd.read_csv('../archive/IPL_Matches_2008_2022.csv')
df2.dataframeName = 'matches.csv'

# %%
df2.head(5)
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  29-05-2022    2022        Final
# 1  1312199  Ahmedabad  27-05-2022    2022  Qualifier 2
# 2  1312198    Kolkata  25-05-2022    2022   Eliminator
# 3  1312197    Kolkata  24-05-2022    2022  Qualifier 1
# 4  1304116     Mumbai  22-05-2022    2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
venue_subset = df2[df2["City"] == 'Centurion']
venue_subset
# Out:
#          ID       City        Date  Season MatchNumber  \
# 837  392237  Centurion  22-05-2009    2009  Semi Final
# 838  392236  Centurion  21-05-2009    2009          56
# 839  392235  Centurion  21-05-2009    2009          55
# 843  392231  Centurion  18-05-2009    2009          51
# 852  392222  Centurion  12-05-2009    2009          42
# 853  392221  Centurion  12-05-2009    2009          41
# 860  392214  Centurion  07-05-2009    2009          34
# 861  392213  Centurion  07-05-2009    2009          33
# 862  392212  Centurion  06-05-2009    2009          32
# 872  392202  Centurion  30-04-2009    2009          22
# 873  392201  Centurion  30-04-2009    2009          21
# 876  392198  Centurion  28-04-2009    2009          18
#
#                            Team1                  Team2            Venue  \
# 837             Delhi Daredevils        Deccan Chargers  SuperSport Park
# 838  Royal Challengers Bangalore        Deccan Chargers  SuperSport Park
# 839             Delhi Daredevils         Mumbai Indians  SuperSport Park
# 843          Chennai Super Kings  Kolkata Knight Riders  SuperSport Park
# 852              Kings XI Punjab         Mumbai Indians  SuperSport Park
# 853  Royal Challengers Bangalore  Kolkata Knight Riders  SuperSport Park
# 860          Chennai Super Kings        Kings XI Punjab  SuperSport Park
# 861  Royal Challengers Bangalore       Rajasthan Royals  SuperSport Park
# 862              Deccan Chargers         Mumbai Indians  SuperSport Park
# 872          Chennai Super Kings       Rajasthan Royals  SuperSport Park
# 873              Deccan Chargers       Delhi Daredevils  SuperSport Park
# 876             Delhi Daredevils       Rajasthan Royals  SuperSport Park
#
#                       TossWinner TossDecision SuperOver  \
# 837              Deccan Chargers        field         N
# 838  Royal Challengers Bangalore          bat         N
# 839             Delhi Daredevils        field         N
# 843          Chennai Super Kings          bat         N
# 852              Kings XI Punjab          bat         N
# 853  Royal Challengers Bangalore        field         N
# 860          Chennai Super Kings          bat         N
# 861             Rajasthan Royals        field         N
# 862              Deccan Chargers          bat         N
# 872             Rajasthan Royals        field         N
# 873             Delhi Daredevils        field         N
# 876             Delhi Daredevils          bat         N
#
#                      WinningTeam    WonBy  Margin method  Player_of_Match  \
# 837              Deccan Chargers  Wickets     6.0    NaN     AC Gilchrist
# 838  Royal Challengers Bangalore     Runs    12.0    NaN        MK Pandey
# 839             Delhi Daredevils  Wickets     4.0    NaN         V Sehwag
# 843        Kolkata Knight Riders  Wickets     7.0    NaN         BJ Hodge
# 852               Mumbai Indians  Wickets     8.0    NaN  Harbhajan Singh
# 853  Royal Challengers Bangalore  Wickets     6.0    NaN      LRPL Taylor
# 860          Chennai Super Kings     Runs    12.0    D/L        ML Hayden
# 861             Rajasthan Royals  Wickets     7.0    NaN          A Singh
# 862              Deccan Chargers     Runs    19.0    NaN        RG Sharma
# 872          Chennai Super Kings     Runs    38.0    NaN         SK Raina
# 873             Delhi Daredevils  Wickets     6.0    NaN        DP Nannes
# 876             Rajasthan Royals  Wickets     5.0    NaN        YK Pathan
#
#                                           Team1Players  \
# 837  ['G Gambhir', 'DA Warner', 'V Sehwag', 'TM Dil...
# 838  ['JH Kallis', 'MK Pandey', 'RE van der Merwe',...
# 839  ['G Gambhir', 'DA Warner', 'V Sehwag', 'TM Dil...
# 843  ['PA Patel', 'GJ Bailey', 'SK Raina', 'MS Dhon...
# 852  ['S Sohal', 'SM Katich', 'IK Pathan', 'KC Sang...
# 853  ['JD Ryder', 'JH Kallis', 'RV Uthappa', 'LRPL ...
# 860  ['S Badrinath', 'ML Hayden', 'SK Raina', 'MS D...
# 861  ['JH Kallis', 'W Jaffer', 'RV Uthappa', 'R Dra...
# 862  ['AC Gilchrist', 'HH Gibbs', 'TL Suman', 'RG S...
# 872  ['PA Patel', 'ML Hayden', 'SK Raina', 'S Badri...
# 873  ['AC Gilchrist', 'HH Gibbs', 'AA Bilakhia', 'R...
# 876  ['G Gambhir', 'V Sehwag', 'AB de Villiers', 'T...
#
#                                           Team2Players      Umpire1  \
# 837  ['AC Gilchrist', 'HH Gibbs', 'AA Bilakhia', 'T...  BR Doctrove
# 838  ['AC Gilchrist', 'HH Gibbs', 'TL Suman', 'A Sy...    IL Howell
# 839  ['ST Jayasuriya', 'SR Tendulkar', 'JP Duminy',...    IL Howell
# 843  ['BB McCullum', 'SC Ganguly', 'BJ Hodge', 'DJ ...   SJA Taufel
# 852  ['ST Jayasuriya', 'DJ Bravo', 'AM Rahane', 'SR...    SS Hazare
# 853  ['BB McCullum', 'SC Ganguly', 'AN Ghosh', 'DJ ...    M Erasmus
# 860  ['S Sohal', 'SM Katich', 'K Goel', 'Yuvraj Sin...    DJ Harper
# 861  ['GC Smith', 'NV Ojha', 'LA Carseldine', 'YK P...  K Hariharan
# 862  ['ST Jayasuriya', 'SR Tendulkar', 'PR Shah', '...    MR Benson
# 872  ['RJ Quiney', 'GC Smith', 'SA Asnodkar', 'RA J...   GAV Baxter
# 873  ['G Gambhir', 'V Sehwag', 'AB de Villiers', 'T...   GAV Baxter
# 876  ['RJ Quiney', 'GC Smith', 'SA Asnodkar', 'PC V...   GAV Baxter
#
#              Umpire2
# 837        DJ Harper
# 838           S Ravi
# 839           S Ravi
# 843        RB Tiffin
# 852      RE Koertzen
# 853        SS Hazare
# 860   TH Wijewardene
# 861        DJ Harper
# 862  HDPK Dharmasena
# 872      RE Koertzen
# 873        AM Saheba
# 876      RE Koertzen

# %%
match_id_list = venue_subset["ID"].to_numpy()
print(match_id_list)
# Out:
# [392237 392236 392235 392231 392222 392221 392214 392213 392212 392202
#  392201 392198]

# %%
m = len(match_id_list)

# %%
player_subset
# Out:
#              ID  innings  overs  ballnumber   batter       bowler non-striker  \
# 1231    1304115        1      5           5  SN Khan    JJ Bumrah     RR Pant
# 1232    1304115        1      5           6  SN Khan    JJ Bumrah     RR Pant
# 1236    1304115        1      6           4  SN Khan   M Markande     RR Pant
# 1239    1304115        1      7           1  SN Khan  RP Meredith     RR Pant
# 1241    1304115        1      7           3  SN Khan  RP Meredith     RR Pant
# ...         ...      ...    ...         ...      ...          ...         ...
# 112202   829745        2     12           1  SN Khan    IC Pandey     V Kohli
# 112205   829745        2     12           4  SN Khan    IC Pandey     V Kohli
# 112208   829745        2     13           1  SN Khan    RA Jadeja     V Kohli
# 112209   829745        2     13           2  SN Khan    RA Jadeja     V Kohli
# 112210   829745        2     13           3  SN Khan    RA Jadeja     V Kohli
#
#        extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 1231          NaN            0           0          0             0
# 1232          NaN            6           0          6             0
# 1236          NaN            1           0          1             0
# 1239          NaN            1           0          1             0
# 1241          NaN            1           0          1             0
# ...           ...          ...         ...        ...           ...
# 112202        NaN            1           0          1             0
# 112205        NaN            1           0          1             0
# 112208        NaN            6           0          6             0
# 112209        NaN            2           0          2             0
# 112210        NaN            0           0          0             0
#
#         isWicketDelivery player_out    kind fielders_involved  \
# 1231                   0        NaN     NaN               NaN
# 1232                   0        NaN     NaN               NaN
# 1236                   0        NaN     NaN               NaN
# 1239                   0        NaN     NaN               NaN
# 1241                   0        NaN     NaN               NaN
# ...                  ...        ...     ...               ...
# 112202                 0        NaN     NaN               NaN
# 112205                 0        NaN     NaN               NaN
# 112208                 0        NaN     NaN               NaN
# 112209                 0        NaN     NaN               NaN
# 112210                 1    SN Khan  caught         MM Sharma
#
#                         BattingTeam
# 1231                 Delhi Capitals
# 1232                 Delhi Capitals
# 1236                 Delhi Capitals
# 1239                 Delhi Capitals
# 1241                 Delhi Capitals
# ...                             ...
# 112202  Royal Challengers Bangalore
# 112205  Royal Challengers Bangalore
# 112208  Royal Challengers Bangalore
# 112209  Royal Challengers Bangalore
# 112210  Royal Challengers Bangalore
#
# [394 rows x 17 columns]

# %%
final_df = []
for i in range(len(player_subset)):
    if player_subset.iat[i,0] in match_id_list:
        final_df.append(player_subset.iloc[i])

# %%
final_df
# Out:
# []

# %%
final_df = pd.DataFrame(final_df)

# %%
final_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Overall
if len(final_df)!=0:
    
    total_runs = final_df["batsman_run"].sum()
    print(total_runs)

    total_innings = len(pd.unique(final_df['ID']))
    print(total_innings)

    total_outs = final_df[final_df["player_out"] == 'DA Warner']
    print(len(total_outs))

    if len(total_outs)==0:
        print("Player not yet dismissed at ground")
    
    else:
        average = total_runs / len(total_outs)
        print(average)

    strike_rate = total_runs / len(final_df) * 100
    print(strike_rate)

    dots = final_df[final_df["batsman_run"] == 0]
    dot_percentage = len(dots)/len(final_df) * 100
    print(dot_percentage)

    boundaries = final_df[final_df["batsman_run"] == 4]
    sixes =  final_df[final_df["batsman_run"] == 6]
    boundary_percentage = len(boundaries) + len(sixes) / len(final_df) * 100
    print(boundary_percentage)

else:
    print("Player not played at ground")
# Out:
# Player not played at ground

# %%
#1st_innings
if len(final_df)==0:
    print("Player not played in ground")
    
else:
    final_df_1 = final_df[final_df["inning"]==1]

    if len(final_df_1)!=0:

        total_runs = final_df_1["batsman_run"].sum()
        print(total_runs)

        total_innings = len(pd.unique(final_df_1['ID']))
        print(total_innings)

        total_outs = final_df_1[final_df_1["player_out"] == 'DA Warner']
        print(len(total_outs))

        if len(total_outs)==0:
            print("Player not yet dismissed at ground")

        else:
            average = total_runs / len(total_outs)
            print(average)

        strike_rate = total_runs / len(final_df_1) * 100
        print(strike_rate)

        dots = final_df_1[final_df_1["batsman_run"] == 0]
        dot_percentage = len(dots)/len(final_df_1) * 100
        print(dot_percentage)

        boundaries = final_df_1[final_df_1["batsman_run"] == 4]
        sixes =  final_df_1[final_df_1["batsman_run"] == 6]
        boundary_percentage = len(boundaries) + len(sixes) / len(final_df_1) * 100
        print(boundary_percentage)
    else:
            print("Player not played at ground in 1st innings")
# Out:
# Player not played in ground

# %%
#2nd_innings
if len(final_df)==0:
    print("Player not played in ground")
    
else:
    final_df_2 = final_df[final_df["innings"]==2]
    
    if len(final_df_2)!=0:
        total_runs = final_df_2["batsman_run"].sum()
        print(total_runs)

        total_innings = len(pd.unique(final_df_2['ID']))
        print(total_innings)

        total_outs = final_df_2[final_df_2["player_out"] == 'DA Warner']
        print(len(total_outs))

        if len(total_outs)==0:
                print("Player not yet dismissed at ground")

        else:
            average = total_runs / len(total_outs)
            print(average)

        strike_rate = total_runs / len(final_df_2) * 100
        print(strike_rate)

        dots = final_df_2[final_df_2["batsman_run"] == 0]
        dot_percentage = len(dots)/len(final_df_2) * 100
        print(dot_percentage)

        boundaries = final_df_2[final_df_2["batsman_run"] == 4]
        sixes =  final_df_2[final_df_2["batsman_run"] == 6]
        boundary_percentage = len(boundaries) + len(sixes) / len(final_df_2) * 100
        print(boundary_percentage)
        
    else:
            print("Player not played at ground in 2nd innings")
# Out:
# Player not played in ground
