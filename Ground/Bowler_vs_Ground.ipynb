# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np 
import os
import pandas as pd

# %%
df1 = pd.read_csv('../archive/IPL_Ball_by_Ball_2008_2022.csv')
df1.dataframeName = 'deliveries.csv'

# %%
df1.head(5)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
len(df1)
# Out:
# 225954

# %%
player_subset = df1[df1["bowler"] == 'I Sharma']
player_subset
# Out:
#              ID  innings  overs  ballnumber          batter    bowler  \
# 25290   1254086        1      0           1  P Simran Singh  I Sharma
# 25291   1254086        1      0           2  P Simran Singh  I Sharma
# 25292   1254086        1      0           3  P Simran Singh  I Sharma
# 25293   1254086        1      0           4  P Simran Singh  I Sharma
# 25294   1254086        1      0           5  P Simran Singh  I Sharma
# ...         ...      ...    ...         ...             ...       ...
# 225947   335982        2     14           3        SB Joshi  I Sharma
# 225948   335982        2     14           4        SB Joshi  I Sharma
# 225949   335982        2     14           5         P Kumar  I Sharma
# 225950   335982        2     14           6        SB Joshi  I Sharma
# 225951   335982        2     14           7         P Kumar  I Sharma
#
#        non-striker extra_type  batsman_run  extras_run  total_run  \
# 25290   MA Agarwal        NaN            0           0          0
# 25291   MA Agarwal        NaN            0           0          0
# 25292   MA Agarwal        NaN            0           0          0
# 25293   MA Agarwal        NaN            0           0          0
# 25294   MA Agarwal        NaN            0           0          0
# ...            ...        ...          ...         ...        ...
# 225947     P Kumar        NaN            0           0          0
# 225948     P Kumar        NaN            1           0          1
# 225949    SB Joshi    legbyes            0           1          1
# 225950     P Kumar        NaN            1           0          1
# 225951    SB Joshi        NaN            0           0          0
#
#         non_boundary  isWicketDelivery player_out kind fielders_involved  \
# 25290              0                 0        NaN  NaN               NaN
# 25291              0                 0        NaN  NaN               NaN
# 25292              0                 0        NaN  NaN               NaN
# 25293              0                 0        NaN  NaN               NaN
# 25294              0                 0        NaN  NaN               NaN
# ...              ...               ...        ...  ...               ...
# 225947             0                 0        NaN  NaN               NaN
# 225948             0                 0        NaN  NaN               NaN
# 225949             0                 0        NaN  NaN               NaN
# 225950             0                 0        NaN  NaN               NaN
# 225951             0                 0        NaN  NaN               NaN
#
#                         BattingTeam
# 25290                  Punjab Kings
# 25291                  Punjab Kings
# 25292                  Punjab Kings
# 25293                  Punjab Kings
# 25294                  Punjab Kings
# ...                             ...
# 225947  Royal Challengers Bangalore
# 225948  Royal Challengers Bangalore
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
#
# [2090 rows x 17 columns]

# %%
df2 = pd.read_csv('../archive/IPL_Matches_2008_2022.csv')
df2.dataframeName = 'matches.csv'

# %%
df2.head(5)
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  29-05-2022    2022        Final
# 1  1312199  Ahmedabad  27-05-2022    2022  Qualifier 2
# 2  1312198    Kolkata  25-05-2022    2022   Eliminator
# 3  1312197    Kolkata  24-05-2022    2022  Qualifier 1
# 4  1304116     Mumbai  22-05-2022    2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
venue_subset = df2[df2["City"] == 'Bangalore']
venue_subset
# Out:
#           ID       City        Date  Season  MatchNumber  \
# 315  1082649  Bangalore  19-05-2017    2017  Qualifier 2
# 316  1082648  Bangalore  17-05-2017    2017   Eliminator
# 327  1082636  Bangalore  07-05-2017    2017           46
# 331  1082633  Bangalore  05-05-2017    2017           43
# 343  1082621  Bangalore  27-04-2017    2017           31
# ..       ...        ...         ...     ...          ...
# 925   336006  Bangalore  05-05-2008    2008           25
# 928   336034  Bangalore  03-05-2008    2008           21
# 935   335996  Bangalore  28-04-2008    2008           15
# 939   335992  Bangalore  26-04-2008    2008           12
# 949   335982  Bangalore  18-04-2008    2008            1
#
#                            Team1                  Team2  \
# 315               Mumbai Indians  Kolkata Knight Riders
# 316          Sunrisers Hyderabad  Kolkata Knight Riders
# 327  Royal Challengers Bangalore  Kolkata Knight Riders
# 331  Royal Challengers Bangalore        Kings XI Punjab
# 343  Royal Challengers Bangalore          Gujarat Lions
# ..                           ...                    ...
# 925  Royal Challengers Bangalore        Kings XI Punjab
# 928  Royal Challengers Bangalore        Deccan Chargers
# 935  Royal Challengers Bangalore    Chennai Super Kings
# 939  Royal Challengers Bangalore       Rajasthan Royals
# 949  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                      Venue                   TossWinner TossDecision  \
# 315  M Chinnaswamy Stadium               Mumbai Indians        field
# 316  M Chinnaswamy Stadium        Kolkata Knight Riders        field
# 327  M Chinnaswamy Stadium        Kolkata Knight Riders        field
# 331  M Chinnaswamy Stadium  Royal Challengers Bangalore        field
# 343  M Chinnaswamy Stadium                Gujarat Lions        field
# ..                     ...                          ...          ...
# 925  M Chinnaswamy Stadium              Kings XI Punjab        field
# 928  M Chinnaswamy Stadium              Deccan Chargers        field
# 935  M Chinnaswamy Stadium          Chennai Super Kings          bat
# 939  M Chinnaswamy Stadium             Rajasthan Royals        field
# 949  M Chinnaswamy Stadium  Royal Challengers Bangalore        field
#
#     SuperOver                  WinningTeam    WonBy  Margin method  \
# 315         N               Mumbai Indians  Wickets     6.0    NaN
# 316         N        Kolkata Knight Riders  Wickets     7.0    D/L
# 327         N        Kolkata Knight Riders  Wickets     6.0    NaN
# 331         N              Kings XI Punjab     Runs    19.0    NaN
# 343         N                Gujarat Lions  Wickets     7.0    NaN
# ..        ...                          ...      ...     ...    ...
# 925         N              Kings XI Punjab  Wickets     6.0    NaN
# 928         N  Royal Challengers Bangalore     Runs     3.0    NaN
# 935         N          Chennai Super Kings     Runs    13.0    NaN
# 939         N             Rajasthan Royals  Wickets     7.0    NaN
# 949         N        Kolkata Knight Riders     Runs   140.0    NaN
#
#      Player_of_Match                                       Team1Players  \
# 315        KV Sharma  ['LMP Simmons', 'PA Patel', 'AT Rayudu', 'RG S...
# 316  NM Coulter-Nile  ['DA Warner', 'S Dhawan', 'KS Williamson', 'Yu...
# 327        SP Narine  ['CH Gayle', 'Mandeep Singh', 'V Kohli', 'AB d...
# 331   Sandeep Sharma  ['Mandeep Singh', 'CH Gayle', 'V Kohli', 'AB d...
# 343           AJ Tye  ['CH Gayle', 'V Kohli', 'AB de Villiers', 'TM ...
# ..               ...                                                ...
# 925      S Sreesanth  ['W Jaffer', 'V Kohli', 'CL White', 'JH Kallis...
# 928          P Kumar  ['B Chipli', 'W Jaffer', 'V Kohli', 'JH Kallis...
# 935         MS Dhoni  ['B Chipli', 'W Jaffer', 'LRPL Taylor', 'JH Ka...
# 939        SR Watson  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...
# 949      BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players       Umpire1  \
# 315  ['CA Lynn', 'SP Narine', 'G Gambhir', 'RV Utha...      NJ Llong
# 316  ['RV Uthappa', 'CA Lynn', 'YK Pathan', 'G Gamb...  AK Chaudhary
# 327  ['CA Lynn', 'SP Narine', 'C de Grandhomme', 'G...   AY Dandekar
# 331  ['HM Amla', 'MJ Guptill', 'SE Marsh', 'M Vohra...   CB Gaffaney
# 343  ['Ishan Kishan', 'BB McCullum', 'SK Raina', 'A...  AK Chaudhary
# ..                                                 ...           ...
# 925  ['SE Marsh', 'JR Hopes', 'RR Sarwan', 'Yuvraj ...      SJ Davis
# 928  ['AC Gilchrist', 'VVS Laxman', 'HH Gibbs', 'RG...   BR Doctrove
# 935  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'SK Ra...   BR Doctrove
# 939  ['GC Smith', 'M Rawat', 'YK Pathan', 'SR Watso...     MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...     Asad Rauf
#
#            Umpire2
# 315    Nitin Menon
# 316    Nitin Menon
# 327  C Shamshuddin
# 331  C Shamshuddin
# 343  C Shamshuddin
# ..             ...
# 925    BR Doctrove
# 928     SL Shastri
# 935      RB Tiffin
# 939      IL Howell
# 949    RE Koertzen
#
# [65 rows x 20 columns]

# %%
match_id_list = venue_subset["ID"].to_numpy()
print(match_id_list)
# Out:
# [1082649 1082648 1082636 1082633 1082621 1082607 1082602  981019  981013
#   980999  980987  980981  980969  980959  980921  980907  829813  829785
#   829771  829763  829745  829737  829719  734049  734035  734005  733999
#   733991  733977  598068  598045  598027  598023  598017  598008  598048
#   597999  548379  548367  548356  548350  548327  548324  548315  548310
#   501266  501255  501247  501244  501232  501205  419157  419148  419145
#   419128  419123  419115  419112  336012  336026  336006  336034  335996
#   335992  335982]

# %%
m = len(match_id_list)

# %%
player_subset
# Out:
#              ID  innings  overs  ballnumber          batter    bowler  \
# 25290   1254086        1      0           1  P Simran Singh  I Sharma
# 25291   1254086        1      0           2  P Simran Singh  I Sharma
# 25292   1254086        1      0           3  P Simran Singh  I Sharma
dtype: object,
#  ID                                        419148
#  innings                                        2
#  overs                                          3
#  ballnumber                                     1
#  batter                                  S Sriram
#  bowler                                  I Sharma
#  non-striker                             R Dravid
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 188548, dtype: object,
#  ID                                        419148
#  innings                                        2
#  overs                                          3
#  ballnumber                                     2
#  batter                                  S Sriram
#  bowler                                  I Sharma
#  non-striker                             R Dravid
#  extra_type                                 wides
#  batsman_run                                    0
#  extras_run                                     2
#  total_run                                      2
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 188549, dtype: object,
#  ID                                        419148
#  innings                                        2
#  overs                                          3
#  ballnumber                                     3
#  batter                                  R Dravid
#  bowler                                  I Sharma
#  non-striker                             S Sriram
#  extra_type                                   NaN
#  batsman_run                                    2
#  extras_run                                     0
#  total_run                                      2
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 188550, dtype: object,
#  ID                                        419148
#  innings                                        2
#  overs                                          3
#  ballnumber                                     4
#  batter                                  R Dravid
#  bowler                                  I Sharma
#  non-striker                             S Sriram
#  extra_type                                   NaN
#  batsman_run                                    1
#  extras_run                                     0
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 188551, dtype: object,
#  ID                                        419148
#  innings                                        2
#  overs                                          3
#  ballnumber                                     5
#  batter                                  S Sriram
#  bowler                                  I Sharma
#  non-striker                             R Dravid
#  extra_type                                   NaN
#  batsman_run                                    1
#  extras_run                                     0
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 188552, dtype: object,
#  ID                                        419148
#  innings                                        2
#  overs                                          3
#  ballnumber                                     6
#  batter                                  R Dravid
#  bowler                                  I Sharma
#  non-striker                             S Sriram
#  extra_type                                   NaN
#  batsman_run                                    1
#  extras_run                                     0
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 188553, dtype: object,
#  ID                                        419148
#  innings                                        2
#  overs                                          3
#  ballnumber                                     7
#  batter                                  S Sriram
#  bowler                                  I Sharma
#  non-striker                             R Dravid
#  extra_type                                   NaN
#  batsman_run                                    4
#  extras_run                                     0
#  total_run                                      4
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 188554, dtype: object,
#  ID                                        419148
#  innings                                        2
#  overs                                          5
#  ballnumber                                     1
#  batter                                  R Dravid
#  bowler                                  I Sharma
#  non-striker                             S Sriram
#  extra_type                                   NaN
#  batsman_run                                    4
# ...
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225860, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                          1
#  ballnumber                                     2
#  batter                                   V Kohli
#  bowler                                  I Sharma
#  non-striker                             W Jaffer
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225861, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                          1
#  ballnumber                                     3
#  batter                                   V Kohli
#  bowler                                  I Sharma
#  non-striker                             W Jaffer
#  extra_type                               legbyes
#  batsman_run                                    0
#  extras_run                                     4
#  total_run                                      4
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225862, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                          1
#  ballnumber                                     4
#  batter                                   V Kohli
#  bowler                                  I Sharma
#  non-striker                             W Jaffer
#  extra_type                                   NaN
#  batsman_run                                    1
#  extras_run                                     0
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225863, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                          1
#  ballnumber                                     5
#  batter                                  W Jaffer
#  bowler                                  I Sharma
#  non-striker                              V Kohli
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225864, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                          1
#  ballnumber                                     6
#  batter                                  W Jaffer
#  bowler                                  I Sharma
#  non-striker                              V Kohli
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225865, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                          3
#  ballnumber                                     1
#  batter                                  W Jaffer
#  bowler                                  I Sharma
#  non-striker                            JH Kallis
#  extra_type                                   NaN
#  batsman_run                                    2
#  extras_run                                     0
#  total_run                                      2
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225873, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                          3
#  ballnumber                                     2
#  batter                                  W Jaffer
#  bowler                                  I Sharma
#  non-striker                            JH Kallis
#  extra_type                                   NaN
#  batsman_run                                    1
#  extras_run                                     0
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225874, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                          3
#  ballnumber                                     3
#  batter                                 JH Kallis
#  bowler                                  I Sharma
#  non-striker                             W Jaffer
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225875, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                          3
#  ballnumber                                     4
#  batter                                 JH Kallis
#  bowler                                  I Sharma
#  non-striker                             W Jaffer
#  extra_type                               legbyes
#  batsman_run                                    0
#  extras_run                                     1
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225876, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                          3
#  ballnumber                                     5
#  batter                                  W Jaffer
#  bowler                                  I Sharma
#  non-striker                            JH Kallis
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225877, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                          3
#  ballnumber                                     6
#  batter                                  W Jaffer
#  bowler                                  I Sharma
#  non-striker                            JH Kallis
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225878, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     1
#  batter                                  SB Joshi
#  bowler                                  I Sharma
#  non-striker                              P Kumar
#  extra_type                                 wides
#  batsman_run                                    0
#  extras_run                                     1
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225945, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     2
#  batter                                  SB Joshi
#  bowler                                  I Sharma
#  non-striker                              P Kumar
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225946, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     3
#  batter                                  SB Joshi
#  bowler                                  I Sharma
#  non-striker                              P Kumar
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225947, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     4
#  batter                                  SB Joshi
#  bowler                                  I Sharma
#  non-striker                              P Kumar
#  extra_type                                   NaN
#  batsman_run                                    1
#  extras_run                                     0
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225948, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     5
#  batter                                   P Kumar
#  bowler                                  I Sharma
#  non-striker                             SB Joshi
#  extra_type                               legbyes
#  batsman_run                                    0
#  extras_run                                     1
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225949, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     6
#  batter                                  SB Joshi
#  bowler                                  I Sharma
#  non-striker                              P Kumar
#  extra_type                                   NaN
#  batsman_run                                    1
#  extras_run                                     0
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225950, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     7
#  batter                                   P Kumar
#  bowler                                  I Sharma
#  non-striker                             SB Joshi
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225951, dtype: object]

# %%
final_df = pd.DataFrame(final_df)

# %%
len(final_df)
# Out:
# 86

# %%
#Overall
if len(final_df)!=0:
    
    extras_wides = final_df[final_df["extra_type"]=='wides'] 
    extras_noballs =  final_df[final_df["extra_type"]=='noballs']
    total_innings = len(pd.unique(final_df['ID']))
    print(total_innings)

    total_runs = final_df["batsman_run"].sum() + extras_wides["total_run"].sum() + extras_noballs["total_run"].sum()

    total_outs = final_df["player_out"].isnull().sum()
    total_outs = len(final_df)-total_outs
    print(total_outs)
    
    if total_outs==0:
        print("Player has not taken any wickets at the ground")
    
    else:
        average = total_runs/total_outs
        print(average)

        strike_rate = len(final_df)/ total_outs
        print(strike_rate)

    economy = total_runs / (len(final_df)/6)
    print(economy)

else:
    print("Player not played at ground")
# Out:
# 4
# 2
# 59.0
# 43.0
# 8.232558139534884

# %%
#1st_innings
if len(final_df)==0:
    print("Player not played in ground")
    
else:
    
    final_df_1 = final_df[final_df["innings"]==1]
    if len(final_df_1)!=0:
        extras_wides = final_df_1[final_df_1["extra_type"]=='wides'] 
        extras_noballs =  final_df_1[final_df_1["extra_type"]=='noballs']

        total_innings = len(pd.unique(final_df_1['ID']))
        print(total_innings)

        total_runs = final_df_1["batsman_run"].sum() + extras_wides["total_run"].sum() + extras_noballs["total_run"].sum()
        print(total_runs)

        total_outs = final_df_1["player_out"].isnull().sum()
        total_outs = len(final_df_1)-total_outs
        print(total_outs)
        
        if total_outs==0:
            print("Player has not taken any wickets at the ground")

        else:
            average = total_runs/total_outs
            print(average)

            strike_rate = len(final_df_1)/ total_outs
            print(strike_rate)

        economy = total_runs / (len(final_df_1)/6)
        print(economy)
        
    else:
            print("Player not played at ground in 1st innings")
# Out:
# Player not played at ground in 1st innings

# %%
#2nd_innings
if len(final_df)==0:
    print("Player not played in ground")
    
else:
    final_df_2 = final_df[final_df["innings"]==2]
    
    if len(final_df_2)!=0:

        extras_wides = final_df_2[final_df_2["extra_type"]=='wides'] 
        extras_noballs =  final_df_2[final_df_2["extra_type"]=='noballs']

        total_innings = len(pd.unique(final_df_2['ID']))
        print(total_innings)

        total_runs = final_df_2["batsman_run"].sum() + extras_wides["total_run"].sum() + extras_noballs["total_run"].sum()
        print(total_runs)

        total_outs = final_df_2["player_out"].isnull().sum()
        total_outs = len(final_df_2)-total_outs
        print(total_outs)
    
        if total_outs==0:
            print("Player has not taken any wickets at the ground")

        else:
            average = total_runs/total_outs
            print(average)

        strike_rate = len(final_df_2)/ total_outs
        print(strike_rate)

        economy = total_runs / (len(final_df_2)/6)
        print(economy)
    
    else:
            print("Player not played at ground in 1st innings")
# Out:
# 4
# 118
# 2
# 59.0
# 43.0
# 8.232558139534884
