# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np 
import os
import pandas as pd

# %%
df1 = pd.read_csv('archive (2)/IPL_Matches_2008_2022.csv')
df1.dataframeName = 'IPL_Matches_2008_2022.csv'

# %%
df1.head(5)
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  29-05-2022    2022        Final
# 1  1312199  Ahmedabad  27-05-2022    2022  Qualifier 2
# 2  1312198    Kolkata  25-05-2022    2022   Eliminator
# 3  1312197    Kolkata  24-05-2022    2022  Qualifier 1
# 4  1304116     Mumbai  22-05-2022    2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %% [markdown]
# Is the toss that important in T20 games, does chasing have a significant advantage
#
# Find out toss outcomes and game outcomes in specific venues
# Just click the drop down list box and choose the stadium
# You will find the what the majority of teams winning the toss here have chosen to do.
# You will also see the percentage of matches won by the team that won the toss

# %%
len(df1)
# Out:
# 950

# %%
venue_subset = df1[df1["Venue"] == 'M Chinnaswamy Stadium']
venue_subset
# Out:
#           ID       City        Date  Season MatchNumber  \
# 200  1178429  Bengaluru  04-05-2019    2019          54
# 205  1178424  Bengaluru  30-04-2019    2019          49
# 212  1178417  Bengaluru  24-04-2019    2019          42
# 216  1178414  Bengaluru  21-04-2019    2019          39
# 234  1178395  Bengaluru  07-04-2019    2019          20
# ..       ...        ...         ...     ...         ...
# 925   336006  Bangalore  05-05-2008    2008          25
# 928   336034  Bangalore  03-05-2008    2008          21
# 935   335996  Bangalore  28-04-2008    2008          15
# 939   335992  Bangalore  26-04-2008    2008          12
# 949   335982  Bangalore  18-04-2008    2008           1
#
#                            Team1                        Team2  \
# 200          Sunrisers Hyderabad  Royal Challengers Bangalore
# 205  Royal Challengers Bangalore             Rajasthan Royals
# 212  Royal Challengers Bangalore              Kings XI Punjab
# ...

# %%
total_games = len(venue_subset)
total_games
# Out:
# 80

# %%
toss_outcome = venue_subset[ venue_subset ["TossWinner"]== venue_subset["WinningTeam"] ]

# %%
toss_winners = len(toss_outcome)
toss_winners
# Out:
# 43

# %%
percentage = toss_winners / total_games * 100

# %%
percentage
# Out:
# 53.75

# %%
percent = len(venue_subset [venue_subset["TossDecision"]=='field']) / total_games * 100
percent
# Out:
# 88.75

# %% [markdown]
# Find out the trends of the ongoing season of IPL - bat first / bowl first

# %%
season_subset = df1 [ df1["Season"] == 2021]
season_subset
# Out:
#           ID       City        Date  Season  MatchNumber  \
# 74   1254117      Dubai  15-10-2021    2021        Final
# 75   1254116    Sharjah  13-10-2021    2021  Qualifier 2
# 76   1254115    Sharjah  11-10-2021    2021   Eliminator
# 77   1254114      Dubai  10-10-2021    2021  Qualifier 1
# 78   1254101      Dubai  08-10-2021    2021           56
# 79   1254088  Abu Dhabi  08-10-2021    2021           55
# 80   1254106    Sharjah  07-10-2021    2021           54
# 81   1254094      Dubai  07-10-2021    2021           53
# 82   1254095  Abu Dhabi  06-10-2021    2021           52
# 83   1254093    Sharjah  05-10-2021    2021           51
# 84   1254110      Dubai  04-10-2021    2021           50
# 85   1254090    Sharjah  03-10-2021    2021           48
# 86   1254109      Dubai  03-10-2021    2021           49
# 87   1254112    Sharjah  02-10-2021    2021           46
# 88   1254089  Abu Dhabi  02-10-2021    2021           47
# ...

# %%
total_games = len(season_subset)
total_games
# Out:
# 60

# %%
season_trends = len(season_subset[ season_subset ["TossWinner"] == season_subset["WinningTeam"] ])
percentage = season_trends / total_games * 100
percentage
# Out:
# 58.333333333333336

# %%
percent = len(season_subset [season_subset["TossDecision"] =='field']) / total_games * 100
percent
# Out:
# 73.33333333333333

# %% [markdown]
# Find out if your team wins if they win the toss. Also, find out how much your team wins the toss.

# %%
team_trends = df1 [ df1 ["Team1"] == "Royal Challengers Bangalore"]
team_trends2 = df1 [ df1["Team2"] == "Royal Challengers Bangalore"] 

total = len(team_trends) + len(team_trends2)

team = len(team_trends[ team_trends ["TossWinner"] == "Royal Challengers Bangalore"])
team = team + len(team_trends2 [team_trends2 ["TossWinner"] == "Royal Challengers Bangalore"])

total_toss_wins = team 
percentage = total_toss_wins / total * 100
percentage
# Out:
# 46.46017699115044

# %%
team1 = team_trends[ team_trends ["TossWinner"] == "Royal Challengers Bangalore"]
team2 = team_trends2 [team_trends2 ["TossWinner"] == "Royal Challengers Bangalore"]

team_wins = len(team1 [team1 ["WinningTeam"] == "Royal Challengers Bangalore"]) + len(team2 [team2 ["WinningTeam"] == "Royal Challengers Bangalore"])

percentage = team_wins / total_toss_wins * 100
percentage
# Out:
# 50.476190476190474

# %% [markdown]
# Find the strength of your opposition. Are they a SRH or a GT

# %%
team_trends = df1 [ df1 ["Team1"] == "Sunrisers Hyderabad"]
team_wins_bat = len(team_trends [ team_trends[ "WinningTeam"] == "Sunrisers Hyderabad"])

team_trends2 = df1 [ df1 ["Team2"] == "Sunrisers Hyderabad"]
team_wins_bowl = len(team_trends [ team_trends[ "WinningTeam"] == "Sunrisers Hyderabad"])


total = team_wins_bat + team_wins_bowl

p1 = team_wins_bat / total * 100

p1

p2 = team_wins_bowl / total * 100

p2
# Out:
# 50.0
