# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np 
import os
import pandas as pd

# %%
df = pd.read_csv('archive/IPL_Matches_2008_2022.csv')
df.dataframeName = 'matches.csv'

# %%
season_subset = df[(df["Season"] == 2022 )]
season_subset
# Out:
#          ID       City        Date  Season  MatchNumber  \
# 0   1312200  Ahmedabad  29-05-2022    2022        Final
# 1   1312199  Ahmedabad  27-05-2022    2022  Qualifier 2
# 2   1312198    Kolkata  25-05-2022    2022   Eliminator
# 3   1312197    Kolkata  24-05-2022    2022  Qualifier 1
# 4   1304116     Mumbai  22-05-2022    2022           70
# ..      ...        ...         ...     ...          ...
# 69  1304051       Pune  29-03-2022    2022            5
# 70  1304050     Mumbai  28-03-2022    2022            4
# 71  1304049     Mumbai  27-03-2022    2022            3
# 72  1304048     Mumbai  27-03-2022    2022            2
# 73  1304047     Mumbai  26-03-2022    2022            1
#
#                           Team1                  Team2  \
# 0              Rajasthan Royals         Gujarat Titans
# 1   Royal Challengers Bangalore       Rajasthan Royals
# 2   Royal Challengers Bangalore   Lucknow Super Giants
# 3              Rajasthan Royals         Gujarat Titans
# 4           Sunrisers Hyderabad           Punjab Kings
# ..                          ...                    ...
# 69             Rajasthan Royals    Sunrisers Hyderabad
# 70         Lucknow Super Giants         Gujarat Titans
# 71  Royal Challengers Bangalore           Punjab Kings
# 72               Mumbai Indians         Delhi Capitals
# 73          Chennai Super Kings  Kolkata Knight Riders
#
#                                             Venue             TossWinner  \
# 0                Narendra Modi Stadium, Ahmedabad       Rajasthan Royals
# 1                Narendra Modi Stadium, Ahmedabad       Rajasthan Royals
# 2                           Eden Gardens, Kolkata   Lucknow Super Giants
# 3                           Eden Gardens, Kolkata         Gujarat Titans
# 4                        Wankhede Stadium, Mumbai    Sunrisers Hyderabad
# ..                                            ...                    ...
# 69  Maharashtra Cricket Association Stadium, Pune    Sunrisers Hyderabad
# 70                       Wankhede Stadium, Mumbai         Gujarat Titans
# 71             Dr DY Patil Sports Academy, Mumbai           Punjab Kings
# 72                      Brabourne Stadium, Mumbai         Delhi Capitals
# 73                       Wankhede Stadium, Mumbai  Kolkata Knight Riders
#
#    TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 0           bat         N               Gujarat Titans  Wickets     7.0
# 1         field         N             Rajasthan Royals  Wickets     7.0
# 2         field         N  Royal Challengers Bangalore     Runs    14.0
# 3         field         N               Gujarat Titans  Wickets     7.0
# 4           bat         N                 Punjab Kings  Wickets     5.0
# ..          ...       ...                          ...      ...     ...
# 69        field         N             Rajasthan Royals     Runs    61.0
# 70        field         N               Gujarat Titans  Wickets     5.0
# 71        field         N                 Punjab Kings  Wickets     5.0
# 72        field         N               Delhi Capitals  Wickets     4.0
# 73        field         N        Kolkata Knight Riders  Wickets     6.0
#
#    method Player_of_Match                                       Team1Players  \
# 0     NaN       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1     NaN      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2     NaN      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3     NaN       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4     NaN   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..    ...             ...                                                ...
# 69    NaN       SV Samson  ['JC Buttler', 'YBK Jaiswal', 'SV Samson', 'D ...
# 70    NaN  Mohammed Shami  ['KL Rahul', 'Q de Kock', 'E Lewis', 'MK Pande...
# 71    NaN        OF Smith  ['F du Plessis', 'Anuj Rawat', 'V Kohli', 'KD ...
# 72    NaN   Kuldeep Yadav  ['RG Sharma', 'Ishan Kishan', 'Anmolpreet Sing...
# 73    NaN        UT Yadav  ['RD Gaikwad', 'DP Conway', 'RV Uthappa', 'AT ...
#
#                                          Team2Players        Umpire1  \
# 0   ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1   ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2   ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3   ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4   ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                ...            ...
# 69  ['KS Williamson', 'Abhishek Sharma', 'RA Tripa...   BNJ Oxenford
# 70  ['Shubman Gill', 'MS Wade', 'V Shankar', 'HH P...      PG Pathak
# 71  ['MA Agarwal', 'S Dhawan', 'PBB Rajapaksa', 'L...    Nitin Menon
# 72  ['PP Shaw', 'TL Seifert', 'Mandeep Singh', 'RR...      RJ Tucker
# 73  ['AM Rahane', 'VR Iyer', 'N Rana', 'SS Iyer', ...   AK Chaudhary
#
#           Umpire2
# 0     Nitin Menon
# 1     Nitin Menon
# 2        MA Gough
# 3       VK Sharma
# 4   NA Patwardhan
# ..            ...
# 69      UV Gandhe
# 70      VK Sharma
# 71       YC Barde
# 72     HAS Khalid
# 73    Nitin Menon
#
# [74 rows x 20 columns]

# %%
team_subset1 = season_subset[season_subset["Team2"] == 'Chennai Super Kings'] 
team_subset2 = season_subset[season_subset["Team1"] == 'Chennai Super Kings'] 

match_id_list_1 = team_subset1["ID"].to_numpy()
match_id_list_2 = team_subset2["ID"].to_numpy()

match_id_list = np.concatenate([match_id_list_1,match_id_list_2])
print(match_id_list)
# Out:
# [1304095 1304084 1304079 1304057 1304114 1304108 1304105 1304101 1304092
#  1304075 1304068 1304063 1304053 1304047]

# %%
df1 = pd.read_csv('archive/IPL_Ball_by_Ball_2008_2022.csv')
df1.dataframeName = 'deliveries.csv'
df1
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# 0        JC Buttler        NaN            0           0          0
# 1        JC Buttler    legbyes            0           1          1
# 2       YBK Jaiswal        NaN            1           0          1
# 3        JC Buttler        NaN            0           0          0
# 4        JC Buttler        NaN            0           0          0
# ...             ...        ...          ...         ...        ...
# 225949     SB Joshi    legbyes            0           1          1
# 225950      P Kumar        NaN            1           0          1
# 225951     SB Joshi        NaN            0           0          0
# 225952      P Kumar      wides            0           1          1
# 225953      P Kumar        NaN            0           0          0
#
#         non_boundary  isWicketDelivery player_out    kind fielders_involved  \
# 0                  0                 0        NaN     NaN               NaN
# 1                  0                 0        NaN     NaN               NaN
# 2                  0                 0        NaN     NaN               NaN
# 3                  0                 0        NaN     NaN               NaN
# 4                  0                 0        NaN     NaN               NaN
# ...              ...               ...        ...     ...               ...
# 225949             0                 0        NaN     NaN               NaN
# 225950             0                 0        NaN     NaN               NaN
# 225951             0                 0        NaN     NaN               NaN
# 225952             0                 0        NaN     NaN               NaN
# 225953             0                 1   SB Joshi  caught       BB McCullum
#
#                         BattingTeam
# 0                  Rajasthan Royals
# 1                  Rajasthan Royals
# 2                  Rajasthan Royals
# 3                  Rajasthan Royals
# 4                  Rajasthan Royals
# ...                             ...
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
# 225952  Royal Challengers Bangalore
# 225953  Royal Challengers Bangalore
#
# [225954 rows x 17 columns]

# %%
final_df = []
for i in range(len(df1)):
    if df1.iat[i,0] in match_id_list:
        final_df.append(df1.iloc[i])

# %%
final_df = pd.DataFrame(final_df)
final_df = final_df[final_df["BattingTeam"]!="Chennai Super Kings"]
final_df
# Out:
#             ID  innings  overs  ballnumber       batter            bowler  \
# 1569   1304114        2      0           1  YBK Jaiswal  Mukesh Choudhary
# 1570   1304114        2      0           2  YBK Jaiswal  Mukesh Choudhary
# 1571   1304114        2      0           3  YBK Jaiswal  Mukesh Choudhary
# 1572   1304114        2      0           4   JC Buttler  Mukesh Choudhary
# 1573   1304114        2      0           5   JC Buttler  Mukesh Choudhary
# ...        ...      ...    ...         ...          ...               ...
# 17907  1304047        2     17           5      SS Iyer          DJ Bravo
# 17908  1304047        2     17           6   SP Jackson          DJ Bravo
# 17909  1304047        2     18           1   SP Jackson          AF Milne
# 17910  1304047        2     18           2      SS Iyer          AF Milne
# 17911  1304047        2     18           3      SS Iyer          AF Milne
#
#        non-striker extra_type  batsman_run  extras_run  total_run  \
# 1569    JC Buttler        NaN            4           0          4
# 1570    JC Buttler        NaN            4           0          4
# 1571    JC Buttler        NaN            1           0          1
# 1572   YBK Jaiswal        NaN            0           0          0
# 1573   YBK Jaiswal        NaN            0           0          0
# ...            ...        ...          ...         ...        ...
# 17907   SP Jackson        NaN            1           0          1
# 17908      SS Iyer        NaN            1           0          1
# 17909      SS Iyer        NaN            1           0          1
# 17910   SP Jackson        NaN            2           0          2
# 17911   SP Jackson        NaN            4           0          4
#
#        non_boundary  isWicketDelivery player_out kind fielders_involved  \
# 1569              0                 0        NaN  NaN               NaN
# 1570              0                 0        NaN  NaN               NaN
# 1571              0                 0        NaN  NaN               NaN
# 1572              0                 0        NaN  NaN               NaN
# 1573              0                 0        NaN  NaN               NaN
# ...             ...               ...        ...  ...               ...
# 17907             0                 0        NaN  NaN               NaN
# 17908             0                 0        NaN  NaN               NaN
# 17909             0                 0        NaN  NaN               NaN
# 17910             0                 0        NaN  NaN               NaN
# 17911             0                 0        NaN  NaN               NaN
#
#                  BattingTeam
# 1569        Rajasthan Royals
# 1570        Rajasthan Royals
# 1571        Rajasthan Royals
# 1572        Rajasthan Royals
# 1573        Rajasthan Royals
# ...                      ...
# 17907  Kolkata Knight Riders
# 17908  Kolkata Knight Riders
# 17909  Kolkata Knight Riders
# 17910  Kolkata Knight Riders
# 17911  Kolkata Knight Riders
#
# [1682 rows x 17 columns]

# %%
n = len(pd.unique(final_df['bowler']))

# %%
n
# Out:
# 14

# %%
bowler_list = final_df["bowler"].unique()

# %%
for i in bowler_list:
    print(i)
# Out:
# Mukesh Choudhary
# Simarjeet Singh
# MJ Santner
# M Pathirana
# MM Ali
# PH Solanki
# DJ Bravo
# M Theekshana
# RA Jadeja
# D Pretorius
# CJ Jordan
# TU Deshpande
# S Dube
# AF Milne
