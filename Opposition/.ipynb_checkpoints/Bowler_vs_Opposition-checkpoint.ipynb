# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np 
import os
import pandas as pd

# %%
df1 = pd.read_csv('../archive/IPL_Ball_by_Ball_2008_2022.csv')
df1.dataframeName = 'deliveries.csv'

# %%
df1.head(5)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals
# 2                 0        NaN  NaN               NaN  Rajasthan Royals
# 3                 0        NaN  NaN               NaN  Rajasthan Royals
# 4                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
len(df1)
# Out:
# 225954

# %%
player_subset = df1[df1["bowler"] == 'I Sharma']
player_subset
# Out:
#              ID  innings  overs  ballnumber          batter    bowler  \
# 25290   1254086        1      0           1  P Simran Singh  I Sharma
# 25291   1254086        1      0           2  P Simran Singh  I Sharma
# 25292   1254086        1      0           3  P Simran Singh  I Sharma
# 25293   1254086        1      0           4  P Simran Singh  I Sharma
# 25294   1254086        1      0           5  P Simran Singh  I Sharma
# ...         ...      ...    ...         ...             ...       ...
# 225947   335982        2     14           3        SB Joshi  I Sharma
# 225948   335982        2     14           4        SB Joshi  I Sharma
# 225949   335982        2     14           5         P Kumar  I Sharma
# 225950   335982        2     14           6        SB Joshi  I Sharma
# 225951   335982        2     14           7         P Kumar  I Sharma
#
#        non-striker extra_type  batsman_run  extras_run  total_run  \
# 25290   MA Agarwal        NaN            0           0          0
# 25291   MA Agarwal        NaN            0           0          0
# 25292   MA Agarwal        NaN            0           0          0
# 25293   MA Agarwal        NaN            0           0          0
# 25294   MA Agarwal        NaN            0           0          0
# ...            ...        ...          ...         ...        ...
# 225947     P Kumar        NaN            0           0          0
# 225948     P Kumar        NaN            1           0          1
# 225949    SB Joshi    legbyes            0           1          1
# 225950     P Kumar        NaN            1           0          1
# 225951    SB Joshi        NaN            0           0          0
#
#         non_boundary  isWicketDelivery player_out kind fielders_involved  \
# 25290              0                 0        NaN  NaN               NaN
# 25291              0                 0        NaN  NaN               NaN
# 25292              0                 0        NaN  NaN               NaN
# 25293              0                 0        NaN  NaN               NaN
# 25294              0                 0        NaN  NaN               NaN
# ...              ...               ...        ...  ...               ...
# 225947             0                 0        NaN  NaN               NaN
# 225948             0                 0        NaN  NaN               NaN
# 225949             0                 0        NaN  NaN               NaN
# 225950             0                 0        NaN  NaN               NaN
# 225951             0                 0        NaN  NaN               NaN
#
#                         BattingTeam
# 25290                  Punjab Kings
# 25291                  Punjab Kings
# 25292                  Punjab Kings
# 25293                  Punjab Kings
# 25294                  Punjab Kings
# ...                             ...
# 225947  Royal Challengers Bangalore
# 225948  Royal Challengers Bangalore
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
#
# [2090 rows x 17 columns]

# %%
df2 = pd.read_csv('../archive/IPL_Matches_2008_2022.csv')
df2.dataframeName = 'matches.csv'

# %%
df2.head(5)
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  29-05-2022    2022        Final
# 1  1312199  Ahmedabad  27-05-2022    2022  Qualifier 2
# 2  1312198    Kolkata  25-05-2022    2022   Eliminator
# 3  1312197    Kolkata  24-05-2022    2022  Qualifier 1
# 4  1304116     Mumbai  22-05-2022    2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# 3             Eden Gardens, Kolkata        Gujarat Titans        field
# 4          Wankhede Stadium, Mumbai   Sunrisers Hyderabad          bat
#
#   SuperOver                  WinningTeam    WonBy  Margin method  \
# 0         N               Gujarat Titans  Wickets     7.0    NaN
# 1         N             Rajasthan Royals  Wickets     7.0    NaN
# 2         N  Royal Challengers Bangalore     Runs    14.0    NaN
# 3         N               Gujarat Titans  Wickets     7.0    NaN
# 4         N                 Punjab Kings  Wickets     5.0    NaN
#
#   Player_of_Match                                       Team1Players  \
# 0       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
#
#                                         Team2Players        Umpire1  \
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2  ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4  ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
#
#          Umpire2
# 0    Nitin Menon
# 1    Nitin Menon
# 2       MA Gough
# 3      VK Sharma
# 4  NA Patwardhan

# %%
team_subset1 = df2[df2["Team2"] == 'Royal Challengers Bangalore'] 
team_subset2 = df2[df2["Team1"] == 'Royal Challengers Bangalore'] 

match_id_list_1 = team_subset1["ID"].to_numpy()
match_id_list_2 = team_subset2["ID"].to_numpy()

match_id_list = np.concatenate([match_id_list_1,match_id_list_2])
print(match_id_list)
# Out:
# [1304113 1304106 1304085 1304068 1304064 1304059 1304052 1254101 1254095
#  1254103 1254083 1254076 1254073 1254058 1216494 1216522 1216519 1216514
#  1216510 1178429 1178421 1178403 1175366 1175362 1136613 1136608 1136605
#  1136599 1136579 1136574 1136571 1136568 1082646 1082628 1082624 1082617
#  1082610 1082598 1082591  981013  981011  980995  980977  980953  980937
#   980931  980927  829821  829807  829803  829795  829779  829757  829749
#   829713  734027  734021  734013  733983  729313  729305  729281  598057
#   598054  598064  598042  598036  598033  598012  598004  548376  548372
#   548362  548360  548344  548336  548331  548318  501271  501260  501252
#   501227  501222  501211  501208  501200  419154  419151  419140  419136
#   419133  419119  419109  336002  336029  336023  336016  336010  335998
#   335985 1312199 1312198 1304100 1304095 1304089 1304082 1304077 1304073
#  1304049 1254115 1254090 1254108 1254113 1254087 1254079 1254067 1254063
#  1237178 1216505 1216502 1216499 1216544 1216531 1216540 1216525 1216547
#  1216534 1178424 1178417 1178414 1178410 1178406 1178395 1175372 1175369
#  1175356 1136611 1136595 1136591 1136589 1136584 1136563 1082636 1082633
#  1082621 1082607 1082602 1082595  981019  980999  980987  980981  980969
#   980959  980921  980907  829819  829813  829785  829771  829763  829745
#   829737  829719  734035  734005  733999  733991  733977  729299  729287
#   598068  598045  598027  598023  598017  598008  598048  597999  548367
#   548356  548350  548327  548324  548315  548310  501270  501268  501266
#   501255  501247  501244  501232  501205  419164  419162  419157  419148
#   419145  419128  419123  419115  419112  392239  392238  392236  392232
#   392224  392221  392218  392213  392208  392204  392199  392194  392191
#   392188  392185  392182  336012  336026  336006  336034  335996  335992
#   335982]

# %%
m = len(match_id_list)

# %%
player_subset = player_subset[player_subset['BattingTeam']=='Royal Challengers Bangalore']

# %%
player_subset
# Out:
#              ID  innings  overs  ballnumber      batter    bowler non-striker  \
# 26980   1254079        1      0           1     V Kohli  I Sharma  D Padikkal
# 26981   1254079        1      0           2  D Padikkal  I Sharma     V Kohli
# 26982   1254079        1      0           3  D Padikkal  I Sharma     V Kohli
# 26983   1254079        1      0           4  D Padikkal  I Sharma     V Kohli
# 26984   1254079        1      0           5  D Padikkal  I Sharma     V Kohli
# ...         ...      ...    ...         ...         ...       ...         ...
# 225947   335982        2     14           3    SB Joshi  I Sharma     P Kumar
# 225948   335982        2     14           4    SB Joshi  I Sharma     P Kumar
# 225949   335982        2     14           5     P Kumar  I Sharma    SB Joshi
# 225950   335982        2     14           6    SB Joshi  I Sharma     P Kumar
# 225951   335982        2     14           7     P Kumar  I Sharma    SB Joshi
#
#        extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 26980         NaN            1           0          1             0
# 26981         NaN            0           0          0             0
# 26982         NaN            0           0          0             0
# 26983         NaN            4           0          4             0
# 26984         NaN            0           0          0             0
# ...           ...          ...         ...        ...           ...
# 225947        NaN            0           0          0             0
# 225948        NaN            1           0          1             0
# 225949    legbyes            0           1          1             0
# 225950        NaN            1           0          1             0
# 225951        NaN            0           0          0             0
#
#         isWicketDelivery player_out kind fielders_involved  \
# 26980                  0        NaN  NaN               NaN
# 26981                  0        NaN  NaN               NaN
# 26982                  0        NaN  NaN               NaN
# 26983                  0        NaN  NaN               NaN
# 26984                  0        NaN  NaN               NaN
# ...                  ...        ...  ...               ...
# 225947                 0        NaN  NaN               NaN
# 225948                 0        NaN  NaN               NaN
# 225949                 0        NaN  NaN               NaN
# 225950                 0        NaN  NaN               NaN
# 225951                 0        NaN  NaN               NaN
#
#                         BattingTeam
# 26980   Royal Challengers Bangalore
# 26981   Royal Challengers Bangalore
# 26982   Royal Challengers Bangalore
# 26983   Royal Challengers Bangalore
# 26984   Royal Challengers Bangalore
# ...                             ...
# 225947  Royal Challengers Bangalore
# 225948  Royal Challengers Bangalore
# 225949  Royal Challengers Bangalore
# 225950  Royal Challengers Bangalore
# 225951  Royal Challengers Bangalore
#  extra_type                               legbyes
#  batsman_run                                    0
#  extras_run                                     1
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225876, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                          3
#  ballnumber                                     5
#  batter                                  W Jaffer
#  bowler                                  I Sharma
#  non-striker                            JH Kallis
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225877, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                          3
#  ballnumber                                     6
#  batter                                  W Jaffer
#  bowler                                  I Sharma
#  non-striker                            JH Kallis
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225878, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     1
#  batter                                  SB Joshi
#  bowler                                  I Sharma
#  non-striker                              P Kumar
#  extra_type                                 wides
#  batsman_run                                    0
#  extras_run                                     1
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225945, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     2
#  batter                                  SB Joshi
#  bowler                                  I Sharma
#  non-striker                              P Kumar
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225946, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     3
#  batter                                  SB Joshi
#  bowler                                  I Sharma
#  non-striker                              P Kumar
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225947, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     4
#  batter                                  SB Joshi
#  bowler                                  I Sharma
#  non-striker                              P Kumar
#  extra_type                                   NaN
#  batsman_run                                    1
#  extras_run                                     0
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225948, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     5
#  batter                                   P Kumar
#  bowler                                  I Sharma
#  non-striker                             SB Joshi
#  extra_type                               legbyes
#  batsman_run                                    0
#  extras_run                                     1
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225949, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     6
#  batter                                  SB Joshi
#  bowler                                  I Sharma
#  non-striker                              P Kumar
#  extra_type                                   NaN
#  batsman_run                                    1
#  extras_run                                     0
#  total_run                                      1
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225950, dtype: object,
#  ID                                        335982
#  innings                                        2
#  overs                                         14
#  ballnumber                                     7
#  batter                                   P Kumar
#  bowler                                  I Sharma
#  non-striker                             SB Joshi
#  extra_type                                   NaN
#  batsman_run                                    0
#  extras_run                                     0
#  total_run                                      0
#  non_boundary                                   0
#  isWicketDelivery                               0
#  player_out                                   NaN
#  kind                                         NaN
#  fielders_involved                            NaN
#  BattingTeam          Royal Challengers Bangalore
#  Name: 225951, dtype: object]

# %%
final_df = pd.DataFrame(final_df)

# %%
len(final_df)
# Out:
# 336

# %%
#Overall
if len(final_df)!=0:
    
    extras_wides = final_df[final_df["extra_type"]=='wides'] 
    extras_noballs =  final_df[final_df["extra_type"]=='noballs']
    total_innings = len(pd.unique(final_df['ID']))
    print(total_innings)

    total_runs = final_df["batsman_run"].sum() + extras_wides["total_run"].sum() + extras_noballs["total_run"].sum()

    total_outs = final_df["player_out"].isnull().sum()
    total_outs = len(final_df)-total_outs
    print(total_outs)
    
    if total_outs==0:
        print("Player has not taken any wickets at the ground")
    
    else:
        average = total_runs/total_outs
        print(average)

        strike_rate = len(final_df)/ total_outs
        print(strike_rate)

    economy = total_runs / (len(final_df)/6)
    print(economy)

else:
    print("Player not played at ground")
# Out:
# 14
# 11
# 38.45454545454545
# 30.545454545454547
# 7.553571428571429

# %%
#1st_innings
if len(final_df)==0:
    print("Player not played in ground")
    
else:
    
    final_df_1 = final_df[final_df["innings"]==1]
    if len(final_df_1)!=0:
        extras_wides = final_df_1[final_df_1["extra_type"]=='wides'] 
        extras_noballs =  final_df_1[final_df_1["extra_type"]=='noballs']

        total_innings = len(pd.unique(final_df_1['ID']))
        print(total_innings)

        total_runs = final_df_1["batsman_run"].sum() + extras_wides["total_run"].sum() + extras_noballs["total_run"].sum()
        print(total_runs)

        total_outs = final_df_1["player_out"].isnull().sum()
        total_outs = len(final_df_1)-total_outs
        print(total_outs)
        
        if total_outs==0:
            print("Player has not taken any wickets at the ground in 1st innings")

        else:
            average = total_runs/total_outs
            print(average)

            strike_rate = len(final_df_1)/ total_outs
            print(strike_rate)

        economy = total_runs / (len(final_df_1)/6)
        print(economy)
        
    else:
            print("Player not played at ground in 1st innings")
# Out:
# 5
# 158
# 4
# 39.5
# 31.25
# 7.5840000000000005

# %%
#2nd_innings
if len(final_df)==0:
    print("Player not played in ground")
    
else:
    final_df_2 = final_df[final_df["innings"]==2]
    
    if len(final_df_2)!=0:

        extras_wides = final_df_2[final_df_2["extra_type"]=='wides'] 
        extras_noballs =  final_df_2[final_df_2["extra_type"]=='noballs']

        total_innings = len(pd.unique(final_df_2['ID']))
        print(total_innings)

        total_runs = final_df_2["batsman_run"].sum() + extras_wides["total_run"].sum() + extras_noballs["total_run"].sum()
        print(total_runs)

        total_outs = final_df_2["player_out"].isnull().sum()
        total_outs = len(final_df_2)-total_outs
        print(total_outs)
    
        if total_outs==0:
            print("Player has not taken any wickets at the ground in 2nd innings")

        else:
            average = total_runs/total_outs
            print(average)

        strike_rate = len(final_df_2)/ total_outs
        print(strike_rate)

        economy = total_runs / (len(final_df_2)/6)
        print(economy)
    
    else:
            print("Player not played at ground in 2nd innings")
# Out:
# 9
# 265
# 7
# 37.857142857142854
# 30.142857142857142
# 7.535545023696683
